# %% [markdown]
# ## custom 7 (lr :  (0.001~0.2) obj:0.5, epoch 200)
# - lr을 높여서 실험을 한번도 진행 해보지 않아 높여서 진행해보았다.
# - custom2에서 mAP값이 높게 나와 obj_loss를 0.5로 낮췄다.
# - epoch은 200이 더 성능이 좋은것을 custom5를 통해 확인하여 200으로 하여 실험을 진행했다.

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1094, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1094 (delta 0), reused 1 (delta 0), pack-reused 1091
# Receiving objects: 100% (1094/1094), 69.85 MiB | 43.88 MiB/s, done.
# Resolving deltas: 100% (522/522), done.

# %%
# !pwd
# %cd yolov7
# !ls
# !conda list wandb
# !pip install wandb 
# !pip install -r requirements.txt
# !pip install pycocotools
# Out:
# /home/minki_kwak01/joon
# /home/minki_kwak01/joon/yolov7
# LICENSE.md   detect.py	 paper		   traced_model.pt
# README.md    export.py	 requirements.txt  train.py
# __pycache__  figure	 runs		   train_aux.py
# cfg	     hubconf.py  scripts	   utils
# data	     inference	 test.py	   wandb
# deploy	     models	 tools		   yolov7-e6e_training.pt

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: juniffel. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## 학습

# %%
# !python train.py \
--workers 8 \
--epoch 200 \
--device 0 \
--batch-size 4 \
--data /home/minki_kwak01/joon/input_file/test.yaml\
--img 960 960 \
--cfg cfg/training/yolov7.yaml \
--name 'custom7' \
--hyp data/hyp.scratch.custom7.yaml \
--entity juniffel \
--artifact_alias 'latest' \
--weights ' '
# Out:
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.12.1+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=4, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='/home/minki_kwak01/joon/input_file/test.yaml', device='0', entity='juniffel', epochs=200, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom7.yaml', image_weights=False, img_size=[960, 960], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='custom7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/custom7', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=4, upload_dataset=False, v5_metric=False, weights=' ', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ##  체크포인트 부터 재시작

# %%
# train p5 models//
# !python train.py \
--resume /home/minki_kwak01/joon/yolov7/runs/train/custom7/weights/last.pt
# Out:
# Resuming training from /home/minki_kwak01/joon/yolov7/runs/train/custom7/weights/last.pt
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.12.1+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=4, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='/home/minki_kwak01/joon/input_file/test.yaml', device='0', entity='juniffel', epochs=200, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom7.yaml', image_weights=False, img_size=[960, 960], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='custom7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/custom7', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=4, upload_dataset=False, v5_metric=False, weights='/home/minki_kwak01/joon/yolov7/runs/train/custom7/weights/last.pt', workers=8, world_size=1)
# ...

# %% [markdown]
# ## 테스트 test.py에서 test.json으로 바꿀것

# %%
# !python test.py \
--data  /home/minki_kwak01/joon/input_file/test.yaml\
--img 960 \
--batch 4 \
--conf 0.001 \
--iou 0.65 \
--device 0 \
--weights  /home/minki_kwak01/joon/yolov7/runs/train/custom7/weights/best.pt\
--name custom7 \
--task 'test' \
--save-json
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.001, data='/home/minki_kwak01/joon/input_file/test.yaml', device='0', exist_ok=False, img_size=960, iou_thres=0.65, name='custom7', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='test', v5_metric=False, verbose=False, weights=['/home/minki_kwak01/joon/yolov7/runs/train/custom7/weights/best.pt'])
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.12.1+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/minki_kwak01/anaconda3/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ## 회고
# - 결과는 큰 변화는 없었고 obj_loss는 여전히 수렴하지 못했다.
# - yolo특성상 배경학습이 객체 학습보다 많이 되서 obj_loss가 높게 나온다고 생각 했는데 내가 생각하지못한 다른이유가 있는 것 같다.
